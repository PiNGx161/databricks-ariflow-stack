# %% [markdown]
# #### Create the external locations required for this project
# 1. Bronze
# 2. Silver
# 3. Gold

# %%
# %sql
CREATE EXTERNAL LOCATION IF NOT EXISTS stock_ex_bronze
 URL "abfss://bronze@databricksstockexchanges.dfs.core.windows.net/"
 WITH (STORAGE CREDENTIAL `stockex_credential`);

# %%
# %sql
CREATE EXTERNAL LOCATION IF NOT EXISTS stock_ex_silver
 URL "abfss://silver@databricksstockexchanges.dfs.core.windows.net/"
 WITH (STORAGE CREDENTIAL `stockex_credential`);

# %%
# %sql
CREATE EXTERNAL LOCATION IF NOT EXISTS stock_ex_gold
 URL "abfss://gold@databricksstockexchanges.dfs.core.windows.net/"
 WITH (STORAGE CREDENTIAL `stockex_credential`);

# %% [markdown]
# ### Create Schema

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS bronze
MANAGED LOCATION "abfss://bronze@databricksstockexchanges.dfs.core.windows.net/"

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS silver
MANAGED LOCATION "abfss://silver@databricksstockexchanges.dfs.core.windows.net/"

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS gold
MANAGED LOCATION "abfss://gold@databricksstockexchanges.dfs.core.windows.net/"
